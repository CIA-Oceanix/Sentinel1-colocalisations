# %%
! git clone https://github.com/CIA-Oceanix/Sentinel1-colocalisations.git
# %cd Sentinel1-colocalisations
# Out:
# Cloning into 'Sentinel1-colocalisations'...
# remote: Enumerating objects: 126, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 126 (delta 54), reused 93 (delta 32), pack-reused 10
# Receiving objects: 100% (126/126), 170.24 MiB | 24.92 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# Checking out files: 100% (30/30), done.
# /content/Sentinel1-colocalisations

# %%
! pip install shutup
! pip install fire
! pip install utm

! pip install --upgrade matplotlib

! pip install basemap
! pip install basemap-data-hires
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shutup
#   Downloading shutup-0.2.0-py3-none-any.whl (1.5 kB)
# Installing collected packages: shutup
# Successfully installed shutup-0.2.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
#      |████████████████████████████████| 87 kB 964 kB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from fire) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from fire) (2.1.0)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115940 sha256=c441a376c102bccfaf41768f73b7412ececaba6cf8ce2ce3ffbc5979e142b113
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# Installing collected packages: fire
# Successfully installed fire-0.4.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting utm
#   Downloading utm-0.7.0.tar.gz (8.7 kB)
# Building wheels for collected packages: utm
#   Building wheel for utm (setup.py) ... done
#   Created wheel for utm: filename=utm-0.7.0-py3-none-any.whl size=6108 sha256=827ddff0d81cb47a04234d9b47232a3ed7176ffb631ae0dbcf1c998ee63674a4
#   Stored in directory: /root/.cache/pip/wheels/a5/b0/12/7ee4fdb0f9fbb4157100bd02390436ed5d58ebfd3c6d6a0886
# Successfully built utm
# Installing collected packages: utm
# Successfully installed utm-0.7.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (3.2.2)
# Collecting matplotlib
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 6.3 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (1.21.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (7.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      |████████████████████████████████| 965 kB 60.3 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib) (4.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Installing collected packages: fonttools, matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# Successfully installed fonttools-4.38.0 matplotlib-3.5.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting basemap
#   Downloading basemap-1.3.6-cp37-cp37m-manylinux1_x86_64.whl (864 kB)
#      |████████████████████████████████| 864 kB 6.8 MB/s
# Collecting basemap-data<1.4,>=1.3.2
#   Downloading basemap_data-1.3.2-py2.py3-none-any.whl (30.5 MB)
#      |████████████████████████████████| 30.5 MB 1.3 MB/s
# Requirement already satisfied: numpy<1.22,>=1.21 in /usr/local/lib/python3.7/dist-packages (from basemap) (1.21.6)
# Collecting pyproj<3.5.0,>=1.9.3
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 48.9 MB/s
# Collecting pyshp<2.4,>=1.2
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 4.1 MB/s
# Requirement already satisfied: matplotlib<3.7,>=1.5 in /usr/local/lib/python3.7/dist-packages (from basemap) (3.5.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib<3.7,>=1.5->basemap) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib<3.7,>=1.5->basemap) (21.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib<3.7,>=1.5->basemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib<3.7,>=1.5->basemap) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib<3.7,>=1.5->basemap) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib<3.7,>=1.5->basemap) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib<3.7,>=1.5->basemap) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib<3.7,>=1.5->basemap) (4.1.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from pyproj<3.5.0,>=1.9.3->basemap) (2022.9.24)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib<3.7,>=1.5->basemap) (1.15.0)
# Installing collected packages: pyshp, pyproj, basemap-data, basemap
# Successfully installed basemap-1.3.6 basemap-data-1.3.2 pyproj-3.2.1 pyshp-2.3.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting basemap-data-hires
#   Downloading basemap_data_hires-1.3.2-py2.py3-none-any.whl (91.1 MB)
#      |████████████████████████████████| 91.1 MB 68 kB/s
# Installing collected packages: basemap-data-hires
# Successfully installed basemap-data-hires-1.3.2

# %%
! pip install MightyMosaic
! pip install global-land-mask
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting MightyMosaic
#   Downloading MightyMosaic-1.2.3-py3-none-any.whl (20 kB)
# Requirement already satisfied: tqdm>=4.32.1 in /usr/local/lib/python3.7/dist-packages (from MightyMosaic) (4.64.1)
# Installing collected packages: MightyMosaic
# Successfully installed MightyMosaic-1.2.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting global-land-mask
#   Downloading global_land_mask-1.0.0-py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 7.0 MB/s
# Installing collected packages: global-land-mask
# Successfully installed global-land-mask-1.0.0

# %%
! python process_s1.py {asf_username} {asf_password} "20170108t015819" NEXRAD
# Out:
# 2022-11-17 08:16:14	Build IW getter
# 2022-11-17 08:16:49	Search the zipnames using the getter
# 2022-11-17 08:16:49	Download the zipnames using ASF
# 2022-11-17 08:17:18	Unzip
# 2022-11-17 08:17:38	Generate the .tiff
# tcmalloc: large alloc 1696759808 bytes == 0x54adc000 @  0x7f2f656d41e7 0x7f2f60acf0ce 0x7f2f60b25cf5 0x7f2f60b25f4f 0x7f2f60bc8673 0x58f62c 0x510bf2 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50d482 0x58fd37 0x50ca37 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b575e 0x4bad99 0x50e18c 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e
# tcmalloc: large alloc 1696759808 bytes == 0xe7562000 @  0x7f2f656d41e7 0x7f2f60acf0ce 0x7f2f60b25cf5 0x7f2f60b25e08 0x7f2f60d6fa50 0x7f2f60d6fe10 0x590ae5 0x510946 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b575e 0x4bad99 0x50e18c 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x5b4ee6 0x58ff2e 0x510325 0x5b4ee6 0x6005a3 0x607796 0x60785c 0x60a436 0x64db82
# tcmalloc: large alloc 1696759808 bytes == 0x54adc000 @  0x7f2f656d41e7 0x7f2f60acf0ce 0x7f2f60b29726 0x7f2f60bbe841 0x4d22a6 0x51041f 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b575e 0x4bad99 0x50e18c 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x5b4ee6 0x58ff2e 0x510325 0x5b4ee6 0x6005a3 0x607796 0x60785c 0x60a436 0x64db82 0x64dd2e 0x7f2f652d1c87
# tcmalloc: large alloc 1696759808 bytes == 0x14d02c000 @  0x7f2f656d6001 0x7f2f60acf1af 0x7f2f60b25c23 0x7f2f60b26a87 0x7f2f60bc8823 0x58f62c 0x510bf2 0x5b4ee6 0x58ff2e 0x510325 0x5b575e 0x58ff2e 0x50d482 0x5b575e 0x58ff2e 0x50d482 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b575e 0x4bad99 0x50e18c 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x5b4ee6
# 2022-11-17 08:18:36	Run the models
# 2022-11-17 08:21:45	Done

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython import display

with open('/content/Sentinel1-colocalisations/outputs/20170108t015819/DL_NEXRAD.png','rb') as f:
    display.Image(data=f.read(), format='png')

# %%
! python process_s1.py {asf_username} {asf_password} "20180117t180947" BiologicalSlicks
# Out:
# 2022-11-17 08:21:59	Build IW getter
# 2022-11-17 08:22:36	Search the zipnames using the getter
# 2022-11-17 08:22:36	Download the zipnames using ASF
# 2022-11-17 08:23:00	Unzip
# 2022-11-17 08:23:16	Generate the .tiff
# tcmalloc: large alloc 1717641216 bytes == 0x52fb8000 @  0x7f23affa81e7 0x7f23ab3a30ce 0x7f23ab3f9cf5 0x7f23ab3f9f4f 0x7f23ab49c673 0x58f62c 0x510bf2 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50d482 0x58fd37 0x50ca37 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b575e 0x4bad99 0x50e18c 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e
# tcmalloc: large alloc 1717641216 bytes == 0xe63ca000 @  0x7f23affa81e7 0x7f23ab3a30ce 0x7f23ab3f9cf5 0x7f23ab3f9e08 0x7f23ab643a50 0x7f23ab643e10 0x590ae5 0x510946 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b575e 0x4bad99 0x50e18c 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x5b4ee6 0x58ff2e 0x510325 0x5b4ee6 0x6005a3 0x607796 0x60785c 0x60a436 0x64db82
# tcmalloc: large alloc 1717641216 bytes == 0x52fb8000 @  0x7f23affa81e7 0x7f23ab3a30ce 0x7f23ab3fd726 0x7f23ab492841 0x4d22a6 0x51041f 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b575e 0x4bad99 0x50e18c 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x5b4ee6 0x58ff2e 0x510325 0x5b4ee6 0x6005a3 0x607796 0x60785c 0x60a436 0x64db82 0x64dd2e 0x7f23afba5c87
# tcmalloc: large alloc 1717641216 bytes == 0x14d1dc000 @  0x7f23affaa001 0x7f23ab3a31af 0x7f23ab3f9c23 0x7f23ab3faa87 0x7f23ab49c823 0x58f62c 0x510bf2 0x5b4ee6 0x58ff2e 0x510325 0x5b575e 0x58ff2e 0x50d482 0x5b575e 0x58ff2e 0x50d482 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e 0x50d482 0x5b575e 0x4bad99 0x50e18c 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x5b4ee6
# 2022-11-17 08:24:05	Run the models
# 2022-11-17 08:27:22	Done

# %%
with open('/content/Sentinel1-colocalisations/outputs/20180117t180947/DL_BiologicalSlicks.png','rb') as f:
    display.Image(data=f.read(), format='png')
