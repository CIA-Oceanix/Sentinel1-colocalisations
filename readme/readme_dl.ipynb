# %%
! git clone https://github.com/CIA-Oceanix/Sentinel1-colocalisations.git
# %cd Sentinel1-colocalisations
# Out:
# Cloning into 'Sentinel1-colocalisations'...
# remote: Enumerating objects: 298, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 298 (delta 52), reused 71 (delta 35), pack-reused 205
# Receiving objects: 100% (298/298), 279.74 MiB | 15.84 MiB/s, done.
# Resolving deltas: 100% (152/152), done.
# Checking out files: 100% (49/49), done.
# /content/Sentinel1-colocalisations

# %%
! pip install shutup
! pip install fire
! pip install utm

! pip install --upgrade matplotlib

! pip install basemap
! pip install basemap-data-hires
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 87 kB 6.3 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115943 sha256=3528ead30d4b8009c0d02c3717b564ed4cd3804f7a936a850687914d74ce94aa
#   Stored in directory: /root/.cache/pip/wheels/1f/10/06/2a990ee4d73a8479fe2922445e8a876d38cfbfed052284c6a1
# Successfully built fire
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for utm: filename=utm-0.7.0-py3-none-any.whl size=6108 sha256=b81ba2a04b82d69ba48f8b114691cf046563f615f1217151908662d0698eff2d
#   Stored in directory: /root/.cache/pip/wheels/65/e2/d8/878a8cc986641056fbfebefc4d8eb64238a7b6d3426e86b447
# Successfully built utm
# ...

# %%
! pip install MightyMosaic
! pip install global-land-mask
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.8 MB 28.7 MB/s
# ...

# %%
with open('logins.py', 'w') as file:
    file.write('ASF_USERNAME = ""\n')
    file.write('ASF_PASSWORD = ""\n')

! python process_s1.py 20170108t015819 NEXRAD
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# tcmalloc: large alloc 1696759808 bytes == 0x53fd2000 @  0x7f231357e1e7 0x7f230eacb994 0x7f230eacc12f 0x7f230eb2a8f5 0x7f230eb2c2cb 0x7f230ebca3ab 0x5aa114 0x49ced5 0x55e571 0x5d7cf1 0x49ced5 0x55e571 0x5d7cf1 0x49ced5 0x4fdff5 0x49ced5 0x5d7c18 0x49ca7c 0x5d7c18 0x49ca7c 0x55e571 0x5d7cf1 0x49ced5 0x55e858 0x5d7cf1 0x5d78b6 0x561051 0x55e571 0x5d7cf1 0x49ced5 0x55e571
# ...

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython import display

with open('/content/Sentinel1-colocalisations/outputs/20170108t015819/DL_NEXRAD.png','rb') as f:
    display.Image(data=f.read(), format='png')

# %%
! python process_s1.py 20180117t180947 BiologicalSlicks
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# tcmalloc: large alloc 1717641216 bytes == 0x53358000 @  0x7f2efd6b21e7 0x7f2ef8bff994 0x7f2ef8c0012f 0x7f2ef8c5e8f5 0x7f2ef8c602cb 0x7f2ef8cfe3ab 0x5aa114 0x49ced5 0x55e571 0x5d7cf1 0x49ced5 0x55e571 0x5d7cf1 0x49ced5 0x4fdff5 0x49ced5 0x5d7c18 0x49ca7c 0x5d7c18 0x49ca7c 0x55e571 0x5d7cf1 0x49ced5 0x55e858 0x5d7cf1 0x5d78b6 0x561051 0x55e571 0x5d7cf1 0x49ced5 0x55e571
# ...

# %%
with open('/content/Sentinel1-colocalisations/outputs/20180117t180947/DL_BiologicalSlicks.png','rb') as f:
    display.Image(data=f.read(), format='png')
